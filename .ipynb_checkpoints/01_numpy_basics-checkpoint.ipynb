# %%
import numpy as np
rng = np.random.default_rng(seed=42)
print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.3.5

# %%
#array creation example
#create an array from python list 
list_data = [1, 2, 3, 4, 5]
arr_from_list = np.array(list_data)
print("array from list:", arr_from_list)
# Out:
# array from list: [1 2 3 4 5]

# %%
type(arr_from_list)
# Out:
# numpy.ndarray

# %%
#creating an array of zeros 
arr_zeros = np.zeros((2, 3)) #2*3 matrix of zeros
print("\narray of zero's :\n", arr_zeros)
# Out:
# array of zero's :
#  [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
#creating an array of ones 
arr_ones = np.ones((2, 3)) #2*3 matrix of ones 
print("\narray of ones :\n", arr_ones)
# Out:
# array of ones :
#  [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
arr_ones.shape
# Out:
# (2, 3)

# %%
arr_ones.ndim
# Out:
# 2
